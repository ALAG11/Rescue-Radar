# %%
import os
import pandas as pd
import numpy as np
import cv2
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import KFold

# Define constants
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 10
K_FOLDS = 5

# Step 1: Create DataFrame
def create_dataframe_from_images(directory):
    data = []
    for filename in os.listdir(directory):
        if filename.endswith(".png"):
            label = "post_disaster" if "post_disaster" in filename else "pre_disaster"
            data.append({
                "image_path": os.path.join(directory, filename),
                "label": label
            })
    df = pd.DataFrame(data)
    return df

train_dir = r'C:\Users\Smilika\Documents\Minor_Project\hold_extracted\geotiffs\hold\images'
df = create_dataframe_from_images(train_dir)

# Step 2: Load and preprocess images
def preprocess_image(image_path, label):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
    image = image / 255.0
    return image, label

def load_dataset(df):
    images = []
    labels = []
    for _, row in df.iterrows():
        image, label = preprocess_image(row['image_path'], row['label'])
        images.append(image)
        labels.append(0 if label == 'pre_disaster' else 1)  # Binary classification: 0 = pre_disaster, 1 = post_disaster
    images = np.array(images)
    labels = np.array(labels)
    return images, labels

images, labels = load_dataset(df)

# Step 3: Define K-Fold Cross-Validation
kf = KFold(n_splits=K_FOLDS, shuffle=True, random_state=42)

def create_disaster_status_model():
    base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)  # Batch Normalization
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.4)(x)  # Dropout layer
    x = BatchNormalization()(x)  # Batch Normalization
    x = Dense(128, activation='relu')(x)
    x = Dropout(0.3)(x)  # Dropout layer
    x = BatchNormalization()(x)  # Batch Normalization
    predictions = Dense(2, activation='softmax')(x)  # Binary classification: Pre or Post
    model = Model(inputs=base_model.input, outputs=predictions)
    
    for layer in base_model.layers:
        layer.trainable = False
    
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

def train_and_evaluate_model(X_train, y_train, X_val, y_val):
    model = create_disaster_status_model()
    model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=EPOCHS,
        batch_size=BATCH_SIZE
    )
    val_loss, val_accuracy = model.evaluate(X_val, y_val)
    print(f"Validation Accuracy: {val_accuracy:.4f}")
    return model

# Step 4: K-Fold Cross-Validation
for fold, (train_index, val_index) in enumerate(kf.split(images)):
    print(f"Fold {fold + 1}")
    X_train, X_val = images[train_index], images[val_index]
    y_train, y_val = labels[train_index], labels[val_index]
    
    # Train and evaluate model
    model = train_and_evaluate_model(X_train, y_train, X_val, y_val)
# Out:
# Fold 1
# Epoch 1/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 32s 501ms/step - accuracy: 0.5931 - loss: 0.8295 - val_accuracy: 0.6684 - val_loss: 0.6075
# Epoch 2/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 420ms/step - accuracy: 0.7177 - loss: 0.5572 - val_accuracy: 0.7139 - val_loss: 0.5595
# Epoch 3/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 428ms/step - accuracy: 0.7357 - loss: 0.5222 - val_accuracy: 0.7193 - val_loss: 0.5626
# Epoch 4/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 421ms/step - accuracy: 0.8093 - loss: 0.4409 - val_accuracy: 0.7273 - val_loss: 0.5509
# Epoch 5/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 422ms/step - accuracy: 0.8043 - loss: 0.4162 - val_accuracy: 0.7433 - val_loss: 0.5641
# Epoch 6/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 452ms/step - accuracy: 0.8289 - loss: 0.3678 - val_accuracy: 0.7460 - val_loss: 0.6009
# Epoch 7/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 421ms/step - accuracy: 0.8487 - loss: 0.3367 - val_accuracy: 0.7273 - val_loss: 0.6197
# Epoch 8/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 427ms/step - accuracy: 0.8840 - loss: 0.2710 - val_accuracy: 0.7193 - val_loss: 0.6542
# Epoch 9/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 455ms/step - accuracy: 0.8803 - loss: 0.2700 - val_accuracy: 0.7032 - val_loss: 0.6947
# Epoch 10/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 21s 450ms/step - accuracy: 0.9224 - loss: 0.2323 - val_accuracy: 0.7193 - val_loss: 0.7352
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 359ms/step - accuracy: 0.6994 - loss: 0.7219
# Validation Accuracy: 0.7193
# Fold 2
# Epoch 1/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 32s 499ms/step - accuracy: 0.5587 - loss: 0.9288 - val_accuracy: 0.6944 - val_loss: 0.5885
# Epoch 2/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 422ms/step - accuracy: 0.7068 - loss: 0.5878 - val_accuracy: 0.7292 - val_loss: 0.5312
# Epoch 3/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 398ms/step - accuracy: 0.7502 - loss: 0.5245 - val_accuracy: 0.7346 - val_loss: 0.5190
# Epoch 4/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 371ms/step - accuracy: 0.7967 - loss: 0.4683 - val_accuracy: 0.7426 - val_loss: 0.5205
# Epoch 5/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - accuracy: 0.8178 - loss: 0.4186 - val_accuracy: 0.7319 - val_loss: 0.5246
# Epoch 6/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 369ms/step - accuracy: 0.8329 - loss: 0.3767 - val_accuracy: 0.7265 - val_loss: 0.5375
# Epoch 7/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - accuracy: 0.8412 - loss: 0.3623 - val_accuracy: 0.7105 - val_loss: 0.5549
# Epoch 8/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 369ms/step - accuracy: 0.8521 - loss: 0.3347 - val_accuracy: 0.7319 - val_loss: 0.5676
# Epoch 9/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - accuracy: 0.8778 - loss: 0.2889 - val_accuracy: 0.7239 - val_loss: 0.5788
# Epoch 10/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 371ms/step - accuracy: 0.8833 - loss: 0.2587 - val_accuracy: 0.7399 - val_loss: 0.6247
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 284ms/step - accuracy: 0.7242 - loss: 0.6729
# Validation Accuracy: 0.7399
# Fold 3
# Epoch 1/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 24s 416ms/step - accuracy: 0.5732 - loss: 0.8719 - val_accuracy: 0.6783 - val_loss: 0.6439
# Epoch 2/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 374ms/step - accuracy: 0.7093 - loss: 0.5920 - val_accuracy: 0.6944 - val_loss: 0.5760
# Epoch 3/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 377ms/step - accuracy: 0.7397 - loss: 0.5333 - val_accuracy: 0.7051 - val_loss: 0.5943
# Epoch 4/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 375ms/step - accuracy: 0.7696 - loss: 0.4857 - val_accuracy: 0.6944 - val_loss: 0.6142
# Epoch 5/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 373ms/step - accuracy: 0.7878 - loss: 0.4439 - val_accuracy: 0.6917 - val_loss: 0.6120
# Epoch 6/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 374ms/step - accuracy: 0.8309 - loss: 0.3516 - val_accuracy: 0.6944 - val_loss: 0.6339
# Epoch 7/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 375ms/step - accuracy: 0.8539 - loss: 0.3169 - val_accuracy: 0.6971 - val_loss: 0.6838
# Epoch 8/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 371ms/step - accuracy: 0.8748 - loss: 0.2851 - val_accuracy: 0.6702 - val_loss: 0.7184
# Epoch 9/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 378ms/step - accuracy: 0.8717 - loss: 0.3035 - val_accuracy: 0.6890 - val_loss: 0.7535
# Epoch 10/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 17s 372ms/step - accuracy: 0.8962 - loss: 0.2475 - val_accuracy: 0.6783 - val_loss: 0.7766
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 301ms/step - accuracy: 0.6835 - loss: 0.7241
# Validation Accuracy: 0.6783
# Fold 4
# Epoch 1/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 404ms/step - accuracy: 0.5445 - loss: 1.0187 - val_accuracy: 0.6676 - val_loss: 0.6114
# Epoch 2/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.6825 - loss: 0.6336 - val_accuracy: 0.7507 - val_loss: 0.4952
# Epoch 3/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 384ms/step - accuracy: 0.7253 - loss: 0.5278 - val_accuracy: 0.7399 - val_loss: 0.5011
# Epoch 4/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 397ms/step - accuracy: 0.8045 - loss: 0.4315 - val_accuracy: 0.7480 - val_loss: 0.5120
# Epoch 5/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 394ms/step - accuracy: 0.8221 - loss: 0.3908 - val_accuracy: 0.7319 - val_loss: 0.5078
# Epoch 6/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 390ms/step - accuracy: 0.8100 - loss: 0.4057 - val_accuracy: 0.7105 - val_loss: 0.5507
# Epoch 7/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 411ms/step - accuracy: 0.8641 - loss: 0.3155 - val_accuracy: 0.7078 - val_loss: 0.5498
# Epoch 8/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 391ms/step - accuracy: 0.8541 - loss: 0.3294 - val_accuracy: 0.6944 - val_loss: 0.5974
# Epoch 9/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 390ms/step - accuracy: 0.8549 - loss: 0.3119 - val_accuracy: 0.7265 - val_loss: 0.5794
# Epoch 10/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 394ms/step - accuracy: 0.8780 - loss: 0.2741 - val_accuracy: 0.7024 - val_loss: 0.6586
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 300ms/step - accuracy: 0.6648 - loss: 0.7255
# Validation Accuracy: 0.7024
# Fold 5
# Epoch 1/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 23s 405ms/step - accuracy: 0.5500 - loss: 0.9353 - val_accuracy: 0.7024 - val_loss: 0.5804
# Epoch 2/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 382ms/step - accuracy: 0.7143 - loss: 0.5856 - val_accuracy: 0.7587 - val_loss: 0.4986
# Epoch 3/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 380ms/step - accuracy: 0.7644 - loss: 0.4926 - val_accuracy: 0.7319 - val_loss: 0.5003
# Epoch 4/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 381ms/step - accuracy: 0.7770 - loss: 0.4784 - val_accuracy: 0.7453 - val_loss: 0.4906
# Epoch 5/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 409ms/step - accuracy: 0.8215 - loss: 0.4004 - val_accuracy: 0.7560 - val_loss: 0.4749
# Epoch 6/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 20s 430ms/step - accuracy: 0.8212 - loss: 0.3906 - val_accuracy: 0.7534 - val_loss: 0.5060
# Epoch 7/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 19s 401ms/step - accuracy: 0.8443 - loss: 0.3431 - val_accuracy: 0.7668 - val_loss: 0.5059
# Epoch 8/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 382ms/step - accuracy: 0.8586 - loss: 0.3289 - val_accuracy: 0.7587 - val_loss: 0.5010
# Epoch 9/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 379ms/step - accuracy: 0.8699 - loss: 0.3082 - val_accuracy: 0.7587 - val_loss: 0.5493
# Epoch 10/10
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 18s 377ms/step - accuracy: 0.9157 - loss: 0.2355 - val_accuracy: 0.7480 - val_loss: 0.5542
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 294ms/step - accuracy: 0.7440 - loss: 0.5444
# Validation Accuracy: 0.7480

# %%
# Step 4: Predict disaster status
def preprocess_image_for_prediction(image_path):
    image, _ = preprocess_image(image_path, None)
    return np.expand_dims(image, axis=0)

def predict_disaster_status(image_path, model):
    image = preprocess_image_for_prediction(image_path)
    prediction = model.predict(image)
    status = np.argmax(prediction, axis=1)[0]
    return "Post-disaster" if status == 1 else "Pre-disaster"

# Example Usage
test_image_path1 = r'C:\Users\Smilika\Documents\Minor_Project\test_extracted\geotiffs\test\images\hurricane-matthew_00000383_post_disaster.png'
test_image_path2 = r'C:\Users\Smilika\Documents\Minor_Project\test_extracted\geotiffs\test\images\hurricane-matthew_00000383_pre_disaster.png'
status = predict_disaster_status(test_image_path, status_model)
print(f"Status: {status}")
status2 = predict_disaster_status(test_image_path2, status_model)
print(f"Status: {status2}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Status: Post-disaster
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Status: Pre-disaster

# %%
model.save('k_fold_mobilenetV2_damange_disast.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
